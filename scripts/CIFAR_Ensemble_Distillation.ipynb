# %%
# %%bash
# # Install Python 3.8 and virtual environment tools
# sudo apt-get install python3.8 python3.8-venv python3.8-dev
#
# # Create clean virtual environment
# python3.8 -m venv --clear gnosis-env
# source gnosis-env/bin/activate
#
# # Clone repo with fresh copy
# rm -rf gnosis
# git clone https://github.com/samuelstanton/gnosis.git
# cd gnosis
#
# # Fix dependencies for Python 3.8 compatibility
# sed -i 's/sklearn/scikit-learn/' requirements.txt
#
# # Install core build dependencies
# pip install --upgrade "pip<23.3.1" setuptools==59.5.0 wheel
#
# # Install PyTorch with CUDA 11.1 (matching Torch 1.10)
# pip install torch==1.10.0+cu113 torchvision==0.11.1+cu113 torchaudio==0.10.0+cu113 -f https://download.pytorch.org/whl/cu113/torch_stable.html
#
# # Install remaining requirements with numpy first
# pip install "numpy<1.24"
# pip install -r requirements.txt --ignore-installed
# pip install -e .
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   libpython3.8 libpython3.8-dev libpython3.8-minimal libpython3.8-stdlib
#   python3.8-distutils python3.8-lib2to3 python3.8-minimal
# Suggested packages:
#   binfmt-support
# The following NEW packages will be installed:
#   libpython3.8 libpython3.8-dev libpython3.8-minimal libpython3.8-stdlib
#   python3.8 python3.8-dev python3.8-distutils python3.8-lib2to3
#   python3.8-minimal python3.8-venv
# 0 upgraded, 10 newly installed, 0 to remove and 22 not upgraded.
# Need to get 14.7 MB of archives.
# After this operation, 48.0 MB of additional disk space will be used.
# Get:1 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 libpython3.8-minimal amd64 3.8.20-1+jammy1 [796 kB]
# Get:2 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 python3.8-minimal amd64 3.8.20-1+jammy1 [2,023 kB]
# Get:3 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 libpython3.8-stdlib amd64 3.8.20-1+jammy1 [1,817 kB]
# Get:4 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 libpython3.8 amd64 3.8.20-1+jammy1 [1,798 kB]
# Get:5 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 libpython3.8-dev amd64 3.8.20-1+jammy1 [4,389 kB]
# Get:6 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 python3.8 amd64 3.8.20-1+jammy1 [440 kB]
# Get:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 python3.8-dev amd64 3.8.20-1+jammy1 [500 kB]
# Get:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 python3.8-lib2to3 all 3.8.20-1+jammy1 [126 kB]
# Get:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 python3.8-distutils all 3.8.20-1+jammy1 [193 kB]
# Get:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 python3.8-venv amd64 3.8.20-1+jammy1 [2,618 kB]
# Fetched 14.7 MB in 32s (461 kB/s)
# Selecting previously unselected package libpython3.8-minimal:amd64.
# (Reading database ... 124935 files and directories currently installed.)
# Preparing to unpack .../0-libpython3.8-minimal_3.8.20-1+jammy1_amd64.deb ...
# Unpacking libpython3.8-minimal:amd64 (3.8.20-1+jammy1) ...
# Selecting previously unselected package python3.8-minimal.
# Preparing to unpack .../1-python3.8-minimal_3.8.20-1+jammy1_amd64.deb ...
# Unpacking python3.8-minimal (3.8.20-1+jammy1) ...
# Selecting previously unselected package libpython3.8-stdlib:amd64.
# Preparing to unpack .../2-libpython3.8-stdlib_3.8.20-1+jammy1_amd64.deb ...
# Unpacking libpython3.8-stdlib:amd64 (3.8.20-1+jammy1) ...
# Selecting previously unselected package libpython3.8:amd64.
# Preparing to unpack .../3-libpython3.8_3.8.20-1+jammy1_amd64.deb ...
# Unpacking libpython3.8:amd64 (3.8.20-1+jammy1) ...
# Selecting previously unselected package libpython3.8-dev:amd64.
# Preparing to unpack .../4-libpython3.8-dev_3.8.20-1+jammy1_amd64.deb ...
# Unpacking libpython3.8-dev:amd64 (3.8.20-1+jammy1) ...
# Selecting previously unselected package python3.8.
# Preparing to unpack .../5-python3.8_3.8.20-1+jammy1_amd64.deb ...
# Unpacking python3.8 (3.8.20-1+jammy1) ...
# Selecting previously unselected package python3.8-dev.
# Preparing to unpack .../6-python3.8-dev_3.8.20-1+jammy1_amd64.deb ...
# Unpacking python3.8-dev (3.8.20-1+jammy1) ...
# Selecting previously unselected package python3.8-lib2to3.
# Preparing to unpack .../7-python3.8-lib2to3_3.8.20-1+jammy1_all.deb ...
# Unpacking python3.8-lib2to3 (3.8.20-1+jammy1) ...
# Selecting previously unselected package python3.8-distutils.
# Preparing to unpack .../8-python3.8-distutils_3.8.20-1+jammy1_all.deb ...
# Unpacking python3.8-distutils (3.8.20-1+jammy1) ...
# Selecting previously unselected package python3.8-venv.
# Preparing to unpack .../9-python3.8-venv_3.8.20-1+jammy1_amd64.deb ...
# Unpacking python3.8-venv (3.8.20-1+jammy1) ...
# Setting up libpython3.8-minimal:amd64 (3.8.20-1+jammy1) ...
# Setting up python3.8-lib2to3 (3.8.20-1+jammy1) ...
# Setting up python3.8-minimal (3.8.20-1+jammy1) ...
# Setting up python3.8-distutils (3.8.20-1+jammy1) ...
# Setting up libpython3.8-stdlib:amd64 (3.8.20-1+jammy1) ...
# Setting up python3.8 (3.8.20-1+jammy1) ...
# Setting up libpython3.8:amd64 (3.8.20-1+jammy1) ...
# Setting up python3.8-venv (3.8.20-1+jammy1) ...
# Setting up libpython3.8-dev:amd64 (3.8.20-1+jammy1) ...
# Setting up python3.8-dev (3.8.20-1+jammy1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Requirement already satisfied: pip<23.3.1 in /content/gnosis-env/lib/python3.8/site-packages (23.0.1)
# Collecting pip<23.3.1
#   Downloading pip-23.3-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 11.1 MB/s eta 0:00:00
# Collecting setuptools==59.5.0
#   Downloading setuptools-59.5.0-py3-none-any.whl (952 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.4/952.4 kB 19.0 MB/s eta 0:00:00
# Collecting wheel
#   Downloading wheel-0.45.1-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 11.1 MB/s eta 0:00:00
# Installing collected packages: wheel, setuptools, pip
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 56.0.0
#     Uninstalling setuptools-56.0.0:
#       Successfully uninstalled setuptools-56.0.0
#   Attempting uninstall: pip
#     Found existing installation: pip 23.0.1
#     Uninstalling pip-23.0.1:
#       Successfully uninstalled pip-23.0.1
# Successfully installed pip-23.3 setuptools-59.5.0 wheel-0.45.1
# Looking in links: https://download.pytorch.org/whl/cu113/torch_stable.html
# Collecting torch==1.10.0+cu113
#   Downloading https://download.pytorch.org/whl/cu113/torch-1.10.0%2Bcu113-cp38-cp38-linux_x86_64.whl (1821.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 GB 869.6 kB/s eta 0:00:00
# Collecting torchvision==0.11.1+cu113
#   Downloading https://download.pytorch.org/whl/cu113/torchvision-0.11.1%2Bcu113-cp38-cp38-linux_x86_64.whl (24.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 74.1 MB/s eta 0:00:00
# Collecting torchaudio==0.10.0+cu113
#   Downloading https://download.pytorch.org/whl/cu113/torchaudio-0.10.0%2Bcu113-cp38-cp38-linux_x86_64.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 60.3 MB/s eta 0:00:00
# Collecting typing-extensions (from torch==1.10.0+cu113)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting numpy (from torchvision==0.11.1+cu113)
#   Downloading numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Collecting pillow!=8.3.0,>=5.3.0 (from torchvision==0.11.1+cu113)
#   Downloading pillow-10.4.0-cp38-cp38-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Downloading pillow-10.4.0-cp38-cp38-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 56.4 MB/s eta 0:00:00
# Downloading numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 97.3 MB/s eta 0:00:00
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Installing collected packages: typing-extensions, pillow, numpy, torch, torchvision, torchaudio
# Successfully installed numpy-1.24.4 pillow-10.4.0 torch-1.10.0+cu113 torchaudio-0.10.0+cu113 torchvision-0.11.1+cu113 typing-extensions-4.12.2
# Collecting numpy<1.24
#   Downloading numpy-1.23.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# Downloading numpy-1.23.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 57.2 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.4
#     Uninstalling numpy-1.24.4:
#       Successfully uninstalled numpy-1.24.4
# Successfully installed numpy-1.23.5
# Collecting git+https://github.com/samuelstanton/upcycle.git@master (from -r requirements.txt (line 17))
#   Cloning https://github.com/samuelstanton/upcycle.git (to revision master) to /tmp/pip-req-build-ocp0knpu
#   Resolved https://github.com/samuelstanton/upcycle.git to commit e2bd601d61a234bea6167266c7f25f566503df4c
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting omegaconf==2.1.0.dev26 (from -r requirements.txt (line 1))
#   Downloading omegaconf-2.1.0.dev26-py3-none-any.whl.metadata (3.5 kB)
# Collecting hydra-core==1.1.0.dev6 (from -r requirements.txt (line 2))
#   Downloading hydra_core-1.1.0.dev6-py3-none-any.whl.metadata (4.2 kB)
# Collecting ray==1.2.0 (from -r requirements.txt (line 3))
#   Downloading ray-1.2.0-cp38-cp38-manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting cloudpickle==1.6.0 (from -r requirements.txt (line 4))
#   Downloading cloudpickle-1.6.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting pickle5==0.0.11 (from -r requirements.txt (line 5))
#   Downloading pickle5-0.0.11.tar.gz (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.1/132.1 kB 3.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting hydra-ray-launcher==1.1.0.dev1 (from -r requirements.txt (line 6))
#   Downloading hydra_ray_launcher-1.1.0.dev1-py3-none-any.whl.metadata (890 bytes)
# Collecting torch==1.10.0 (from -r requirements.txt (line 7))
#   Downloading torch-1.10.0-cp38-cp38-manylinux1_x86_64.whl.metadata (24 kB)
# Collecting torchvision==0.11.1 (from -r requirements.txt (line 8))
#   Downloading torchvision-0.11.1-cp38-cp38-manylinux1_x86_64.whl.metadata (8.8 kB)
# Collecting torchtext==0.11.0 (from -r requirements.txt (line 9))
#   Downloading torchtext-0.11.0-cp38-cp38-manylinux1_x86_64.whl.metadata (9.1 kB)
# Collecting scikit-learn==1.0.1 (from -r requirements.txt (line 10))
#   Downloading scikit_learn-1.0.1-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (10 kB)
# Collecting pandas==1.2.1 (from -r requirements.txt (line 11))
#   Downloading pandas-1.2.1-cp38-cp38-manylinux1_x86_64.whl.metadata (4.7 kB)
# Collecting tabulate==0.8.7 (from -r requirements.txt (line 12))
#   Downloading tabulate-0.8.7-py3-none-any.whl.metadata (23 kB)
# Collecting s3fs==0.4.2 (from -r requirements.txt (line 13))
#   Downloading s3fs-0.4.2-py3-none-any.whl.metadata (1.3 kB)
# Collecting tqdm==4.56.0 (from -r requirements.txt (line 14))
#   Downloading tqdm-4.56.0-py2.py3-none-any.whl.metadata (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.0/56.0 kB 2.3 MB/s eta 0:00:00
# Collecting tensorboardX==2.1 (from -r requirements.txt (line 15))
#   Downloading tensorboardX-2.1-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting seaborn==0.11.1 (from -r requirements.txt (line 16))
#   Downloading seaborn-0.11.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting antlr4-python3-runtime==4.8 (from omegaconf==2.1.0.dev26->-r requirements.txt (line 1))
#   Downloading antlr4-python3-runtime-4.8.tar.gz (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.4/112.4 kB 11.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting PyYAML>=5.1.* (from omegaconf==2.1.0.dev26->-r requirements.txt (line 1))
#   Downloading PyYAML-6.0.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting importlib-resources (from hydra-core==1.1.0.dev6->-r requirements.txt (line 2))
#   Downloading importlib_resources-6.4.5-py3-none-any.whl.metadata (4.0 kB)
# Collecting aiohttp (from ray==1.2.0->-r requirements.txt (line 3))
#   Downloading aiohttp-3.10.11-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting aiohttp-cors (from ray==1.2.0->-r requirements.txt (line 3))
#   Downloading aiohttp_cors-0.7.0-py3-none-any.whl.metadata (20 kB)
# Collecting aioredis (from ray==1.2.0->-r requirements.txt (line 3))
#   Downloading aioredis-2.0.1-py3-none-any.whl.metadata (15 kB)
# Collecting click>=7.0 (from ray==1.2.0->-r requirements.txt (line 3))
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting colorama (from ray==1.2.0->-r requirements.txt (line 3))
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting colorful (from ray==1.2.0->-r requirements.txt (line 3))
#   Downloading colorful-0.5.6-py2.py3-none-any.whl.metadata (16 kB)
# Collecting filelock (from ray==1.2.0->-r requirements.txt (line 3))
#   Downloading filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting gpustat (from ray==1.2.0->-r requirements.txt (line 3))
#   Downloading gpustat-1.1.1.tar.gz (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.1/98.1 kB 9.2 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting grpcio>=1.28.1 (from ray==1.2.0->-r requirements.txt (line 3))
#   Downloading grpcio-1.70.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Collecting jsonschema (from ray==1.2.0->-r requirements.txt (line 3))
#   Downloading jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting msgpack<2.0.0,>=1.0.0 (from ray==1.2.0->-r requirements.txt (line 3))
#   Downloading msgpack-1.1.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.4 kB)
# Collecting numpy>=1.16 (from ray==1.2.0->-r requirements.txt (line 3))
#   Using cached numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Collecting protobuf>=3.8.0 (from ray==1.2.0->-r requirements.txt (line 3))
#   Downloading protobuf-5.29.3-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting py-spy>=0.2.0 (from ray==1.2.0->-r requirements.txt (line 3))
#   Downloading py_spy-0.4.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (16 kB)
# Collecting requests (from ray==1.2.0->-r requirements.txt (line 3))
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting redis>=3.5.0 (from ray==1.2.0->-r requirements.txt (line 3))
#   Downloading redis-5.2.1-py3-none-any.whl.metadata (9.1 kB)
# Collecting opencensus (from ray==1.2.0->-r requirements.txt (line 3))
#   Downloading opencensus-0.11.4-py2.py3-none-any.whl.metadata (12 kB)
# Collecting prometheus-client>=0.7.1 (from ray==1.2.0->-r requirements.txt (line 3))
#   Downloading prometheus_client-0.21.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting boto3==1.17.17 (from hydra-ray-launcher==1.1.0.dev1->-r requirements.txt (line 6))
#   Downloading boto3-1.17.17-py2.py3-none-any.whl.metadata (6.0 kB)
# Collecting typing-extensions (from torch==1.10.0->-r requirements.txt (line 7))
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting pillow!=8.3.0,>=5.3.0 (from torchvision==0.11.1->-r requirements.txt (line 8))
#   Using cached pillow-10.4.0-cp38-cp38-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Collecting scipy>=1.1.0 (from scikit-learn==1.0.1->-r requirements.txt (line 10))
#   Downloading scipy-1.10.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 kB 4.9 MB/s eta 0:00:00
# Collecting joblib>=0.11 (from scikit-learn==1.0.1->-r requirements.txt (line 10))
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn==1.0.1->-r requirements.txt (line 10))
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting python-dateutil>=2.7.3 (from pandas==1.2.1->-r requirements.txt (line 11))
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2017.3 (from pandas==1.2.1->-r requirements.txt (line 11))
#   Downloading pytz-2025.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting botocore>=1.12.91 (from s3fs==0.4.2->-r requirements.txt (line 13))
#   Downloading botocore-1.37.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting fsspec>=0.6.0 (from s3fs==0.4.2->-r requirements.txt (line 13))
#   Downloading fsspec-2025.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting six (from tensorboardX==2.1->-r requirements.txt (line 15))
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting matplotlib>=2.2 (from seaborn==0.11.1->-r requirements.txt (line 16))
#   Downloading matplotlib-3.7.5-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (5.7 kB)
# Collecting botocore>=1.12.91 (from s3fs==0.4.2->-r requirements.txt (line 13))
#   Downloading botocore-1.20.112-py2.py3-none-any.whl.metadata (5.6 kB)
# Collecting jmespath<1.0.0,>=0.7.1 (from boto3==1.17.17->hydra-ray-launcher==1.1.0.dev1->-r requirements.txt (line 6))
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting s3transfer<0.4.0,>=0.3.0 (from boto3==1.17.17->hydra-ray-launcher==1.1.0.dev1->-r requirements.txt (line 6))
#   Downloading s3transfer-0.3.7-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting randomname (from upcycle==0.0.1->-r requirements.txt (line 17))
#   Downloading randomname-0.2.1.tar.gz (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 5.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting urllib3<1.27,>=1.25.4 (from botocore>=1.12.91->s3fs==0.4.2->-r requirements.txt (line 13))
#   Downloading urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 4.7 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1 (from matplotlib>=2.2->seaborn==0.11.1->-r requirements.txt (line 16))
#   Downloading contourpy-1.1.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.9 kB)
# Collecting cycler>=0.10 (from matplotlib>=2.2->seaborn==0.11.1->-r requirements.txt (line 16))
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=2.2->seaborn==0.11.1->-r requirements.txt (line 16))
#   Downloading fonttools-4.56.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 9.7 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1 (from matplotlib>=2.2->seaborn==0.11.1->-r requirements.txt (line 16))
#   Downloading kiwisolver-1.4.7-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (6.3 kB)
# Collecting packaging>=20.0 (from matplotlib>=2.2->seaborn==0.11.1->-r requirements.txt (line 16))
#   Using cached packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib>=2.2->seaborn==0.11.1->-r requirements.txt (line 16))
#   Downloading pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# Collecting zipp>=3.1.0 (from importlib-resources->hydra-core==1.1.0.dev6->-r requirements.txt (line 2))
#   Downloading zipp-3.20.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting async-timeout>=4.0.3 (from redis>=3.5.0->ray==1.2.0->-r requirements.txt (line 3))
#   Downloading async_timeout-5.0.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp->ray==1.2.0->-r requirements.txt (line 3))
#   Downloading aiohappyeyeballs-2.4.4-py3-none-any.whl.metadata (6.1 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->ray==1.2.0->-r requirements.txt (line 3))
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting attrs>=17.3.0 (from aiohttp->ray==1.2.0->-r requirements.txt (line 3))
#   Downloading attrs-25.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp->ray==1.2.0->-r requirements.txt (line 3))
#   Downloading frozenlist-1.5.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->ray==1.2.0->-r requirements.txt (line 3))
#   Downloading multidict-6.1.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Collecting yarl<2.0,>=1.12.0 (from aiohttp->ray==1.2.0->-r requirements.txt (line 3))
#   Downloading yarl-1.15.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.2/56.2 kB 4.6 MB/s eta 0:00:00
# Collecting nvidia-ml-py>=11.450.129 (from gpustat->ray==1.2.0->-r requirements.txt (line 3))
#   Downloading nvidia_ml_py-12.570.86-py3-none-any.whl.metadata (8.7 kB)
# Collecting psutil>=5.6.0 (from gpustat->ray==1.2.0->-r requirements.txt (line 3))
#   Downloading psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting blessed>=1.17.1 (from gpustat->ray==1.2.0->-r requirements.txt (line 3))
#   Downloading blessed-1.20.0-py2.py3-none-any.whl.metadata (13 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema->ray==1.2.0->-r requirements.txt (line 3))
#   Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting pkgutil-resolve-name>=1.3.10 (from jsonschema->ray==1.2.0->-r requirements.txt (line 3))
#   Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl.metadata (624 bytes)
# Collecting referencing>=0.28.4 (from jsonschema->ray==1.2.0->-r requirements.txt (line 3))
#   Downloading referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema->ray==1.2.0->-r requirements.txt (line 3))
#   Downloading rpds_py-0.20.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting opencensus-context>=0.1.3 (from opencensus->ray==1.2.0->-r requirements.txt (line 3))
#   Downloading opencensus_context-0.1.3-py2.py3-none-any.whl.metadata (3.3 kB)
# Collecting google-api-core<3.0.0,>=1.0.0 (from opencensus->ray==1.2.0->-r requirements.txt (line 3))
#   Downloading google_api_core-2.24.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting fire (from randomname->upcycle==0.0.1->-r requirements.txt (line 17))
#   Downloading fire-0.7.0.tar.gz (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 8.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting charset-normalizer<4,>=2 (from requests->ray==1.2.0->-r requirements.txt (line 3))
#   Downloading charset_normalizer-3.4.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests->ray==1.2.0->-r requirements.txt (line 3))
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting certifi>=2017.4.17 (from requests->ray==1.2.0->-r requirements.txt (line 3))
#   Downloading certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Collecting wcwidth>=0.1.4 (from blessed>=1.17.1->gpustat->ray==1.2.0->-r requirements.txt (line 3))
#   Downloading wcwidth-0.2.13-py2.py3-none-any.whl.metadata (14 kB)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.2.0->-r requirements.txt (line 3))
#   Downloading googleapis_common_protos-1.68.0-py2.py3-none-any.whl.metadata (5.1 kB)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.2.0->-r requirements.txt (line 3))
#   Downloading proto_plus-1.26.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting google-auth<3.0.dev0,>=2.14.1 (from google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.2.0->-r requirements.txt (line 3))
#   Downloading google_auth-2.38.0-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting propcache>=0.2.0 (from yarl<2.0,>=1.12.0->aiohttp->ray==1.2.0->-r requirements.txt (line 3))
#   Downloading propcache-0.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting termcolor (from fire->randomname->upcycle==0.0.1->-r requirements.txt (line 17))
#   Downloading termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.2.0->-r requirements.txt (line 3))
#   Downloading cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.2.0->-r requirements.txt (line 3))
#   Downloading pyasn1_modules-0.4.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.2.0->-r requirements.txt (line 3))
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.2.0->-r requirements.txt (line 3))
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Downloading omegaconf-2.1.0.dev26-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.3/72.3 kB 6.8 MB/s eta 0:00:00
# Downloading hydra_core-1.1.0.dev6-py3-none-any.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.2/141.2 kB 14.0 MB/s eta 0:00:00
# Downloading ray-1.2.0-cp38-cp38-manylinux2014_x86_64.whl (47.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 MB 22.4 MB/s eta 0:00:00
# Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Downloading hydra_ray_launcher-1.1.0.dev1-py3-none-any.whl (16 kB)
# Downloading torch-1.10.0-cp38-cp38-manylinux1_x86_64.whl (881.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 881.9/881.9 MB 1.5 MB/s eta 0:00:00
# Downloading torchvision-0.11.1-cp38-cp38-manylinux1_x86_64.whl (23.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 50.5 MB/s eta 0:00:00
# Downloading torchtext-0.11.0-cp38-cp38-manylinux1_x86_64.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 113.1 MB/s eta 0:00:00
# Downloading scikit_learn-1.0.1-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (25.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.9/25.9 MB 80.1 MB/s eta 0:00:00
# Downloading pandas-1.2.1-cp38-cp38-manylinux1_x86_64.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 112.6 MB/s eta 0:00:00
# Downloading tabulate-0.8.7-py3-none-any.whl (24 kB)
# Downloading s3fs-0.4.2-py3-none-any.whl (19 kB)
# Downloading tqdm-4.56.0-py2.py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 7.3 MB/s eta 0:00:00
# Downloading tensorboardX-2.1-py2.py3-none-any.whl (308 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.8/308.8 kB 27.0 MB/s eta 0:00:00
# Downloading seaborn-0.11.1-py3-none-any.whl (285 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.0/285.0 kB 26.5 MB/s eta 0:00:00
# Downloading boto3-1.17.17-py2.py3-none-any.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.3/130.3 kB 13.7 MB/s eta 0:00:00
# Downloading botocore-1.20.112-py2.py3-none-any.whl (7.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 83.3 MB/s eta 0:00:00
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 9.4 MB/s eta 0:00:00
# Downloading fsspec-2025.2.0-py3-none-any.whl (184 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.5/184.5 kB 18.1 MB/s eta 0:00:00
# Downloading grpcio-1.70.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 109.9 MB/s eta 0:00:00
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 27.1 MB/s eta 0:00:00
# Downloading matplotlib-3.7.5-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (9.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 113.0 MB/s eta 0:00:00
# Downloading importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Downloading msgpack-1.1.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (381 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.5/381.5 kB 33.1 MB/s eta 0:00:00
# Using cached numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# Using cached pillow-10.4.0-cp38-cp38-manylinux_2_28_x86_64.whl (4.5 MB)
# Downloading prometheus_client-0.21.1-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.7/54.7 kB 5.5 MB/s eta 0:00:00
# Downloading protobuf-5.29.3-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 kB 787.0 kB/s eta 0:00:00
# Downloading py_spy-0.4.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 85.7 MB/s eta 0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 21.1 MB/s eta 0:00:00
# Downloading pytz-2025.1-py2.py3-none-any.whl (507 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.9/507.9 kB 38.0 MB/s eta 0:00:00
# Downloading PyYAML-6.0.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (746 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 746.5/746.5 kB 53.6 MB/s eta 0:00:00
# Downloading redis-5.2.1-py3-none-any.whl (261 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.5/261.5 kB 22.4 MB/s eta 0:00:00
# Downloading scipy-1.10.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 58.4 MB/s eta 0:00:00
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Downloading aiohttp-3.10.11-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 68.7 MB/s eta 0:00:00
# Downloading aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Downloading aioredis-2.0.1-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.2/71.2 kB 6.7 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading colorful-0.5.6-py2.py3-none-any.whl (201 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.4/201.4 kB 20.8 MB/s eta 0:00:00
# Downloading filelock-3.16.1-py3-none-any.whl (16 kB)
# Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.5/88.5 kB 9.4 MB/s eta 0:00:00
# Downloading opencensus-0.11.4-py2.py3-none-any.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 12.8 MB/s eta 0:00:00
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 6.1 MB/s eta 0:00:00
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading aiohappyeyeballs-2.4.4-py3-none-any.whl (14 kB)
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Downloading attrs-25.1.0-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.2/63.2 kB 6.7 MB/s eta 0:00:00
# Downloading blessed-1.20.0-py2.py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 6.0 MB/s eta 0:00:00
# Downloading certifi-2025.1.31-py3-none-any.whl (166 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.4/166.4 kB 17.0 MB/s eta 0:00:00
# Downloading charset_normalizer-3.4.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.7/144.7 kB 15.0 MB/s eta 0:00:00
# Downloading contourpy-1.1.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.1/301.1 kB 25.3 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.56.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 102.3 MB/s eta 0:00:00
# Downloading frozenlist-1.5.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.1/243.1 kB 21.4 MB/s eta 0:00:00
# Downloading google_api_core-2.24.1-py3-none-any.whl (160 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.1/160.1 kB 16.8 MB/s eta 0:00:00
# Downloading idna-3.10-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 7.3 MB/s eta 0:00:00
# Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Downloading kiwisolver-1.4.7-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 67.5 MB/s eta 0:00:00
# Downloading multidict-6.1.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.7/129.7 kB 12.7 MB/s eta 0:00:00
# Downloading nvidia_ml_py-12.570.86-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 4.6 MB/s eta 0:00:00
# Downloading opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Using cached packaging-24.2-py3-none-any.whl (65 kB)
# Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl (4.7 kB)
# Downloading psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (277 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.0/278.0 kB 27.7 MB/s eta 0:00:00
# Downloading pyparsing-3.1.4-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 12.4 MB/s eta 0:00:00
# Downloading referencing-0.35.1-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.20.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (360 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 360.8/360.8 kB 34.7 MB/s eta 0:00:00
# Downloading s3transfer-0.3.7-py2.py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 4.8 MB/s eta 0:00:00
# Downloading urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 14.8 MB/s eta 0:00:00
# Downloading yarl-1.15.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.0/319.0 kB 29.3 MB/s eta 0:00:00
# Downloading zipp-3.20.2-py3-none-any.whl (9.2 kB)
# Downloading google_auth-2.38.0-py2.py3-none-any.whl (210 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.8/210.8 kB 20.7 MB/s eta 0:00:00
# Downloading googleapis_common_protos-1.68.0-py2.py3-none-any.whl (164 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.0/165.0 kB 17.2 MB/s eta 0:00:00
# Downloading propcache-0.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (213 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.6/213.6 kB 22.0 MB/s eta 0:00:00
# Downloading proto_plus-1.26.0-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 3.3 MB/s eta 0:00:00
# Downloading wcwidth-0.2.13-py2.py3-none-any.whl (34 kB)
# Downloading termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Downloading pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.5/181.5 kB 19.6 MB/s eta 0:00:00
# Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 8.6 MB/s eta 0:00:00
# Building wheels for collected packages: pickle5, antlr4-python3-runtime, upcycle, gpustat, randomname, fire
#   Building wheel for pickle5 (setup.py): started
#   Building wheel for pickle5 (setup.py): finished with status 'done'
#   Created wheel for pickle5: filename=pickle5-0.0.11-cp38-cp38-linux_x86_64.whl size=259983 sha256=8bcee7fe0dff858d221d100519224327c85394e7b6469443e0a32605515bd685
#   Stored in directory: /root/.cache/pip/wheels/25/d4/61/dbd8edd1a0d656be7b4267c85db3b61951eb60016a0154a122
#   Building wheel for antlr4-python3-runtime (setup.py): started
#   Building wheel for antlr4-python3-runtime (setup.py): finished with status 'done'
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.8-py3-none-any.whl size=141229 sha256=327b5e7afe3cce971af683c1e8520e09bf32478cc61cda6c02861d3fb4953b79
#   Stored in directory: /root/.cache/pip/wheels/c8/d0/ab/d43c02eaddc5b9004db86950802442ad9a26f279c619e28da0
#   Building wheel for upcycle (setup.py): started
#   Building wheel for upcycle (setup.py): finished with status 'done'
#   Created wheel for upcycle: filename=upcycle-0.0.1-py3-none-any.whl size=8008 sha256=8440ac2a355a53b86b9d2fe822e7db5fb7f94a1003b75c331374a1ad126063c5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-y9jr67qq/wheels/91/b9/16/10ec252e87605a2c148867b8f1c6291911d93d3b8e443ccaab
#   Building wheel for gpustat (pyproject.toml): started
#   Building wheel for gpustat (pyproject.toml): finished with status 'done'
#   Created wheel for gpustat: filename=gpustat-1.1.1-py3-none-any.whl size=26563 sha256=815e27d4e49425089b1b824fe3e8d4b8b9ab7a93e43762284910a3d4058c06f8
#   Stored in directory: /root/.cache/pip/wheels/0e/91/24/e76d33670e72d0ff13fe908a9f8e4eb8507c4c195898617aac
#   Building wheel for randomname (setup.py): started
#   Building wheel for randomname (setup.py): finished with status 'done'
#   Created wheel for randomname: filename=randomname-0.2.1-py3-none-any.whl size=89210 sha256=43b306d1cb603985ae524e3a0d4d9957e020b3c468d73268982c61ba9a9ef831
#   Stored in directory: /root/.cache/pip/wheels/79/21/26/e27418b4dfcb6f6434bb7c0d6377bd1fcaafaa5e79537408ff
#   Building wheel for fire (setup.py): started
#   Building wheel for fire (setup.py): finished with status 'done'
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114261 sha256=de45b8a6fc6567338ef7c8aefafa2f12f1aa764361af4fe770dddd870c6ea751
#   Stored in directory: /root/.cache/pip/wheels/e4/c0/6a/3b7584a4fa718f4d38126c56287b00665949885a3aaea27235
# Successfully built pickle5 antlr4-python3-runtime upcycle gpustat randomname fire
# Installing collected packages: wcwidth, tabulate, pytz, py-spy, pickle5, opencensus-context, nvidia-ml-py, colorful, antlr4-python3-runtime, zipp, urllib3, typing-extensions, tqdm, threadpoolctl, termcolor, six, rpds-py, PyYAML, pyparsing, pyasn1, psutil, protobuf, propcache, prometheus-client, pkgutil-resolve-name, pillow, packaging, numpy, msgpack, kiwisolver, joblib, jmespath, idna, grpcio, fsspec, frozenlist, fonttools, filelock, cycler, colorama, cloudpickle, click, charset-normalizer, certifi, cachetools, attrs, async-timeout, aiohappyeyeballs, torch, tensorboardX, scipy, rsa, requests, referencing, redis, python-dateutil, pyasn1-modules, proto-plus, omegaconf, multidict, importlib-resources, googleapis-common-protos, fire, contourpy, blessed, aiosignal, aioredis, yarl, torchvision, torchtext, scikit-learn, randomname, pandas, matplotlib, jsonschema-specifications, hydra-core, gpustat, google-auth, botocore, seaborn, s3transfer, s3fs, jsonschema, google-api-core, aiohttp, upcycle, opencensus, boto3, aiohttp-cors, ray, hydra-ray-launcher
# Successfully installed PyYAML-6.0.2 aiohappyeyeballs-2.4.4 aiohttp-3.10.11 aiohttp-cors-0.7.0 aioredis-2.0.1 aiosignal-1.3.1 antlr4-python3-runtime-4.8 async-timeout-5.0.1 attrs-25.1.0 blessed-1.20.0 boto3-1.17.17 botocore-1.20.112 cachetools-5.5.2 certifi-2025.1.31 charset-normalizer-3.4.1 click-8.1.8 cloudpickle-1.6.0 colorama-0.4.6 colorful-0.5.6 contourpy-1.1.1 cycler-0.12.1 filelock-3.16.1 fire-0.7.0 fonttools-4.56.0 frozenlist-1.5.0 fsspec-2025.2.0 google-api-core-2.24.1 google-auth-2.38.0 googleapis-common-protos-1.68.0 gpustat-1.1.1 grpcio-1.70.0 hydra-core-1.1.0.dev6 hydra-ray-launcher-1.1.0.dev1 idna-3.10 importlib-resources-6.4.5 jmespath-0.10.0 joblib-1.4.2 jsonschema-4.23.0 jsonschema-specifications-2023.12.1 kiwisolver-1.4.7 matplotlib-3.7.5 msgpack-1.1.0 multidict-6.1.0 numpy-1.23.5 nvidia-ml-py-12.570.86 omegaconf-2.1.0.dev26 opencensus-0.11.4 opencensus-context-0.1.3 packaging-24.2 pandas-1.2.1 pickle5-0.0.11 pillow-10.4.0 pkgutil-resolve-name-1.3.10 prometheus-client-0.21.1 propcache-0.2.0 proto-plus-1.26.0 protobuf-5.29.3 psutil-7.0.0 py-spy-0.4.0 pyasn1-0.6.1 pyasn1-modules-0.4.1 pyparsing-3.1.4 python-dateutil-2.9.0.post0 pytz-2025.1 randomname-0.2.1 ray-1.2.0 redis-5.2.1 referencing-0.35.1 requests-2.32.3 rpds-py-0.20.1 rsa-4.9 s3fs-0.4.2 s3transfer-0.3.7 scikit-learn-1.0.1 scipy-1.10.1 seaborn-0.11.1 six-1.17.0 tabulate-0.8.7 tensorboardX-2.1 termcolor-2.4.0 threadpoolctl-3.5.0 torch-1.10.0+cu113 torchtext-0.11.0 torchvision-0.11.1+cu113 tqdm-4.56.0 typing-extensions-4.12.2 upcycle-0.0.1 urllib3-1.26.20 wcwidth-0.2.13 yarl-1.15.2 zipp-3.20.2
# Obtaining file:///content/gnosis
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Installing collected packages: gnosis
#   Running setup.py develop for gnosis
# Successfully installed gnosis-0.1.0
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 10.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Cloning into 'gnosis'...
#   Running command git clone --filter=blob:none --quiet https://github.com/samuelstanton/upcycle.git /tmp/pip-req-build-ocp0knpu
# DEPRECATION: omegaconf 2.1.0.dev26 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# DEPRECATION: omegaconf 2.1.0.dev26 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
# %%bash
# # Activate the virtual environment
# source gnosis-env/bin/activate
#
# # Downgrade protobuf to version 3.20.3
# pip install protobuf==3.20.3
# Out:
# Collecting protobuf==3.20.3
#   Downloading protobuf-3.20.3-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (679 bytes)
# Downloading protobuf-3.20.3-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 9.1 MB/s eta 0:00:00
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.3
#     Uninstalling protobuf-5.29.3:
#       Successfully uninstalled protobuf-5.29.3
# Successfully installed protobuf-3.20.3
# DEPRECATION: omegaconf 2.1.0.dev26 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %% [markdown]
# Upload gan_checkpoint.zip and unzip:

# %%
# !unzip gan_checkpoint.zip
# Out:
# Archive:  gan_checkpoint.zip
#    creating: content/data/
#    creating: content/data/datasets/
#    creating: content/data/datasets/.ipynb_checkpoints/
#    creating: content/data/experiments/
#    creating: content/data/experiments/image_classification/
#    creating: content/data/experiments/image_classification/student_resnet_56_self_distil/
#   inflating: content/data/experiments/image_classification/student_resnet_56_self_distil/hydra_config.txt
#  extracting: content/data/experiments/image_classification/student_resnet_56_self_distil/image_classification.log
#    creating: content/data/experiments/image_classification/student_resnet_56_self_distil/atomic_row_3/
#    creating: content/data/experiments/image_classification/student_resnet_56_self_distil/atomic_row_3/2025-02-18_16-37-32/
#   inflating: content/data/experiments/image_classification/student_resnet_56_self_distil/atomic_row_3/2025-02-18_16-37-32/events.out.tfevents.1739896654.dd3f7962e45a
#    creating: content/data/experiments/image_classification/student_resnet_56_self_distil/atomic_row_3/2025-02-18_16-37-32/.hydra/
#   inflating: content/data/experiments/image_classification/student_resnet_56_self_distil/atomic_row_3/2025-02-18_16-37-32/.hydra/config.yaml
#   inflating: content/data/experiments/image_classification/student_resnet_56_self_distil/atomic_row_3/2025-02-18_16-37-32/teacher_init_0.ckpt
#    creating: content/data/experiments/image_classification/student_resnet_56_self_distil/every_mayo_3/
#    creating: content/data/experiments/image_classification/student_resnet_56_self_distil/every_mayo_3/2025-02-18_16-38-39/
#   inflating: content/data/experiments/image_classification/student_resnet_56_self_distil/every_mayo_3/2025-02-18_16-38-39/events.out.tfevents.1739896721.dd3f7962e45a
#   inflating: content/data/experiments/image_classification/student_resnet_56_self_distil/every_mayo_3/2025-02-18_16-38-39/student_init.ckpt
#   inflating: content/data/experiments/image_classification/student_resnet_56_self_distil/every_mayo_3/2025-02-18_16-38-39/teacher_0.ckpt
#    creating: content/data/experiments/image_classification/student_resnet_56_self_distil/every_mayo_3/2025-02-18_16-38-39/.hydra/
#   inflating: content/data/experiments/image_classification/student_resnet_56_self_distil/every_mayo_3/2025-02-18_16-38-39/.hydra/config.yaml
#    creating: content/data/experiments/image_classification/student_resnet_56_self_distil/.hydra/
#   inflating: content/data/experiments/image_classification/student_resnet_56_self_distil/.hydra/overrides.yaml
#   inflating: content/data/experiments/image_classification/student_resnet_56_self_distil/.hydra/hydra.yaml
#   inflating: content/data/experiments/image_classification/student_resnet_56_self_distil/.hydra/config.yaml
#   inflating: content/data/experiments/image_classification/student_resnet_56_self_distil/multirun.yaml
#    creating: content/data/experiments/image_classification/test/
#    creating: content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/
#   inflating: content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/hydra_config.txt
#  extracting: content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/image_classification.log
#    creating: content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/.hydra/
#   inflating: content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/.hydra/overrides.yaml
#   inflating: content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/.hydra/hydra.yaml
#   inflating: content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/.hydra/config.yaml
#   inflating: content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/multirun.yaml
#    creating: content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/central_rapids_0/
#    creating: content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/central_rapids_0/2025-02-18_16-34-10/
#   inflating: content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/central_rapids_0/2025-02-18_16-34-10/events.out.tfevents.1739896472.dd3f7962e45a
#    creating: content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/central_rapids_0/2025-02-18_16-34-10/.hydra/
#   inflating: content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/central_rapids_0/2025-02-18_16-34-10/.hydra/config.yaml
#   inflating: content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/central_rapids_0/2025-02-18_16-34-10/teacher_init_0.ckpt
#    creating: content/data/experiments/image_generation/
#    creating: content/data/experiments/image_generation/test/
#    creating: content/data/experiments/image_generation/test/sngan_cifar100_v0.1.0/
#   inflating: content/data/experiments/image_generation/test/sngan_cifar100_v0.1.0/hydra_config.txt
#    creating: content/data/experiments/image_generation/test/sngan_cifar100_v0.1.0/glass_bottle_0/
#    creating: content/data/experiments/image_generation/test/sngan_cifar100_v0.1.0/glass_bottle_0/2025-02-18_16-35-08/
#   inflating: content/data/experiments/image_generation/test/sngan_cifar100_v0.1.0/glass_bottle_0/2025-02-18_16-35-08/events.out.tfevents.1739896509.dd3f7962e45a
#    creating: content/data/experiments/image_generation/test/sngan_cifar100_v0.1.0/glass_bottle_0/2025-02-18_16-35-08/.hydra/
#   inflating: content/data/experiments/image_generation/test/sngan_cifar100_v0.1.0/glass_bottle_0/2025-02-18_16-35-08/.hydra/config.yaml
#   inflating: content/data/experiments/image_generation/test/sngan_cifar100_v0.1.0/glass_bottle_0/2025-02-18_16-35-08/generator_100000.ckpt
#  extracting: content/data/experiments/image_generation/test/sngan_cifar100_v0.1.0/image_generation.log
#    creating: content/data/experiments/image_generation/test/sngan_cifar100_v0.1.0/.hydra/
#   inflating: content/data/experiments/image_generation/test/sngan_cifar100_v0.1.0/.hydra/overrides.yaml
#   inflating: content/data/experiments/image_generation/test/sngan_cifar100_v0.1.0/.hydra/hydra.yaml
#   inflating: content/data/experiments/image_generation/test/sngan_cifar100_v0.1.0/.hydra/config.yaml
#   inflating: content/data/experiments/image_generation/test/sngan_cifar100_v0.1.0/multirun.yaml

# %%
# !mv /content/content/data /content/

# %% [markdown]
# Upload teachers_combined.zip and unzip:

# %%
# !unzip teachers_combined.zip
# Out:
# Archive:  teachers_combined.zip
#    creating: content/content/
#    creating: content/content/data/
#    creating: content/content/data/experiments/
#    creating: content/content/data/experiments/image_classification/
#    creating: content/content/data/experiments/image_classification/test/
#    creating: content/content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/
#    creating: content/content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/paper_wraith_5/
#    creating: content/content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/paper_wraith_5/2025-02-17_20-47-46/
#   inflating: content/content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/paper_wraith_5/2025-02-17_20-47-46/teacher_0.ckpt
#   inflating: content/content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/paper_wraith_5/2025-02-17_20-47-46/events.out.tfevents.1739825290.c422f5110f90
#    creating: content/content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/paper_wraith_5/2025-02-17_20-47-46/.hydra/
#   inflating: content/content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/paper_wraith_5/2025-02-17_20-47-46/.hydra/config.yaml
#   inflating: content/content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/paper_wraith_5/2025-02-17_20-47-46/teacher_init_0.ckpt
#   inflating: content/content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/paper_wraith_5/2025-02-17_20-47-46/teacher_0_train_metrics.csv
#    creating: content/content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/ordered_enfilade_4/
#    creating: content/content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/ordered_enfilade_4/2025-02-17_18-03-56/
#   inflating: content/content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/ordered_enfilade_4/2025-02-17_18-03-56/teacher_0.ckpt
#    creating: content/content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/ordered_enfilade_4/2025-02-17_18-03-56/.hydra/
#   inflating: content/content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/ordered_enfilade_4/2025-02-17_18-03-56/.hydra/config.yaml
#   inflating: content/content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/ordered_enfilade_4/2025-02-17_18-03-56/events.out.tfevents.1739815437.1b510fae1f17
#   inflating: content/content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/ordered_enfilade_4/2025-02-17_18-03-56/teacher_init_0.ckpt
#   inflating: content/content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/ordered_enfilade_4/2025-02-17_18-03-56/teacher_0_train_metrics.csv
#    creating: content/content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/leather_sofa_3/
#    creating: content/content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/leather_sofa_3/2025-02-17_17-19-29/
#   inflating: content/content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/leather_sofa_3/2025-02-17_17-19-29/teacher_0.ckpt
#    creating: content/content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/leather_sofa_3/2025-02-17_17-19-29/.hydra/
#   inflating: content/content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/leather_sofa_3/2025-02-17_17-19-29/.hydra/config.yaml
#   inflating: content/content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/leather_sofa_3/2025-02-17_17-19-29/events.out.tfevents.1739812771.1b510fae1f17
#   inflating: content/content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/leather_sofa_3/2025-02-17_17-19-29/teacher_init_0.ckpt
#   inflating: content/content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/leather_sofa_3/2025-02-17_17-19-29/teacher_0_train_metrics.csv

# %% [markdown]
# 50k (doing 0.8)

# %%
# !source gnosis-env/bin/activate && python gnosis/scripts/image_classification.py \
  -m trial_id=3 exp_name=student_resnet_56_self_distil \
  classifier.depth=56 \
  augmentation.transforms_list=[horizontal_flip,crop] \
  dataloader.batch_size=128 \
  trainer.lr_scheduler.eta_min=0. \
  distill_loader.synth_ratio=0.8 \
  trainer.num_epochs=20 \
  teacher.ckpt_dir="/content/content/content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube"

# %% [markdown]
# DO NOT look below im (emirhan) just trying something

# %%
# !source gnosis-env/bin/activate && python gnosis/scripts/image_classification.py \
  -m trial_id=3 exp_name=student_resnet_56_self_distil \
  classifier.depth=56 \
  augmentation.transforms_list=[horizontal_flip,crop] \
  dataloader.batch_size=128 \
  trainer.lr_scheduler.eta_min=0. \
  distill_loader.synth_ratio=0.8 \
  trainer.num_epochs=20 \
  teacher.ckpt_dir="/content/content/content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/leather_sofa_3"
# Out:
# /content/gnosis-env/lib/python3.8/site-packages/hydra/core/default_element.py:122: UserWarning: In 'loss/ts_fwd_cross_ent': Usage of deprecated keyword in package header '# @package _group_'.
# See https://hydra.cc/docs/next/upgrades/1.0_to_1.1/changes_to_package_header for more information
#   warnings.warn(
# /content/gnosis-env/lib/python3.8/site-packages/hydra/core/default_element.py:122: UserWarning: In 'logger/local': Usage of deprecated keyword in package header '# @package _group_'.
# See https://hydra.cc/docs/next/upgrades/1.0_to_1.1/changes_to_package_header for more information
#   warnings.warn(
# [2025-02-25 14:08:08,850][HYDRA] Launching 1 jobs locally
# [2025-02-25 14:08:08,850][HYDRA] 	#0 : trial_id=3 exp_name=student_resnet_56_self_distil classifier.depth=56 augmentation.transforms_list=[horizontal_flip,crop] dataloader.batch_size=128 trainer.lr_scheduler.eta_min=0.0 distill_loader.synth_ratio=0.8 trainer.num_epochs=20 teacher.ckpt_dir=/content/content/content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/leather_sofa_3
# dataset:
#   init:
#     _target_: torchvision.datasets.CIFAR100
#     root: data/datasets/cifar100
#     download: true
#   name: cifar100
#   num_classes: 100
#   input_size: 32
#   shuffle_train_targets:
#     enabled: false
#     seed: 0
#     ratio: 1.0
#   subsample:
#     ratio: 1.0
#     seed: 0
#     split: 0
#   statistics:
#     mean_statistics:
#     - 0.5071
#     - 0.4867
#     - 0.4408
#     std_statistics:
#     - 0.2675
#     - 0.2565
#     - 0.2761
#     max:
#     - 1.0
#     - 1.0
#     - 1.0
#     min:
#     - 0.0
#     - 0.0
#     - 0.0
# classifier:
#   _target_: gnosis.models.PreResNet
#   name: preresnet
#   num_classes: 100
#   depth: 56
#   input_size: 32
#   skip_connections: true
# density_model:
#   _target_: gnosis.models.SNGAN
#   _recursive_: false
#   name: sngan
#   ckpt_dir: test/sngan_cifar100_v0.1.0
#   ckpt_pattern: '*generator_100000.ckpt'
#   gen_cfg:
#     _target_: gnosis.models.sngan.Generator
#     img_channels: 3
#     z_dim: 128
#     k: 256
#   disc_cfg:
#     _target_: gnosis.models.sngan.Discriminator
#     img_channels: 3
#     k: 128
#     out_size: 1
# logger:
#   _target_: upcycle.logging.DataFrameLogger
#   log_dir: ./mean_profile_3/2025-02-25_14-08-09
# loss:
#   name: ts_fwd_cross_ent
#   alpha: 0.0
#   init:
#     _target_: gnosis.distillation.TeacherStudentFwdCrossEntLoss
# augmentation:
#   random_apply:
#     _target_: torchvision.transforms.RandomApply
#     p: 1.0
#   rotation:
#     _target_: torchvision.transforms.RandomRotation
#     degrees: 90
#   crop:
#     _target_: torchvision.transforms.RandomCrop
#     size: 32
#     padding: 4
#   horizontal_flip:
#     _target_: torchvision.transforms.RandomHorizontalFlip
#   vertical_flip:
#     _target_: torchvision.transforms.RandomVerticalFlip
#   perspective:
#     _target_: torchvision.transforms.RandomPerspective
#     distortion_scale: 0.5
#     p: 0.5
#   grayscale:
#     _target_: torchvision.transforms.RandomGrayscale
#     p: 0.1
#   colorjitter:
#     _target_: torchvision.transforms.ColorJitter
#     brightness: 0.2
#     contrast: 0.2
#     saturation: 0.2
#     hue: 0.2
#   gaussian_blur:
#     _target_: torchvision.transforms.GaussianBlur
#     kernel_size: 3
#     sigma:
#     - 0.1
#     - 2.0
#   transforms_list:
#   - horizontal_flip
#   - crop
#   normalization: unitcube
# teacher:
#   name: preresnet
#   depth: 56
#   num_components: 1
#   use_ckpts: true
#   ckpt_init:
#     type: null
#     loc_param: 0.0
#   shuffle_ckpts: false
#   ckpt_dir: /content/content/content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/leather_sofa_3
# trainer:
#   num_epochs: 20
#   eval_period: 10
#   eval_dataset: test
#   optimizer:
#     _target_: torch.optim.SGD
#     lr: 0.05
#     weight_decay: 0.0001
#     momentum: 0.9
#     nesterov: true
#   lr_scheduler:
#     _target_: torch.optim.lr_scheduler.CosineAnnealingLR
#     T_max: 20
#     eta_min: 0.0
#   distill_teacher: true
#   synth_aug:
#     ratio: 0.0
#   freeze_bn: false
# dataloader:
#   _target_: torch.utils.data.DataLoader
#   batch_size: 128
#   shuffle: true
# distill_loader:
#   _target_: gnosis.distillation.dataloaders.DistillLoader
#   splits:
#   - 0
#   temp: 4.0
#   mixup_alpha: 0.0
#   mixup_portion: 1.0
#   batch_size: 128
#   shuffle: true
#   drop_last: false
#   synth_ratio: 0.8
# seed: 3
# trial_id: 3
# project_name: gnosis
# version: v0.1.0
# dataset_dir: data/datasets
# project_dir: cwd
# data_dir: data/experiments/image_classification
# exp_name: student_resnet_56_self_distil
# job_name: mean_profile_3
# timestamp: 2025-02-25_14-08-09
# log_dir: data/experiments/image_classification/student_resnet_56_self_distil
# ckpt_store: local
# s3_bucket: null
#
# GPU available: True
# Files already downloaded and verified
# Files already downloaded and verified
# ==== 1 teacher checkpoint(s) matching *teacher_?.ckpt loaded successfully ====
# using checkpoints [0]
# 0: /content/content/content/data/experiments/image_classification/test/preresnet56_cifar100_unitcube/leather_sofa_3/2025-02-17_17-19-29/teacher_0.ckpt
# ==== 1 generator checkpoint(s) loaded successfully ====
# using checkpoints [0]
# 0: /content/data/experiments/image_generation/test/sngan_cifar100_v0.1.0/glass_bottle_0/2025-02-18_16-35-08/generator_100000.ckpt
# ==== ensembling teacher classifiers ====
# [eval] Loss: 0.000 | Acc: 0.000 (0/0):   0% 0/1924 [00:00<?, ?it/s]/content/gnosis-env/lib/python3.8/site-packages/torch/nn/functional.py:3631: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   warnings.warn(
# [eval] Loss: 0.558 | Acc: 83.742 (41871/50000): 100% 1924/1924 [05:17<00:00,  6.07it/s]
# [eval] Loss: 1.404 | Acc: 63.580 (6358/10000): 100% 79/79 [00:03<00:00, 21.56it/s]
# ==== distilling student classifier ====
# [eval] Loss: 30.247 | Acc: 1.000 (100/10000): 100% 79/79 [00:05<00:00, 13.72it/s]
# [distill] epoch: 1 | lr: 0.0500 | loss: 16.472 | acc: 18.48% (9240/50000) | agree : 21.39% (52675/246248): 100% 1924/1924 [08:23<00:00,  3.82it/s]
# [distill] epoch: 2 | lr: 0.0497 | loss: 15.113 | acc: 40.26% (20128/50000) | agree : 36.47% (89808/246248): 100% 1924/1924 [08:23<00:00,  3.82it/s]
# [distill] epoch: 3 | lr: 0.0488 | loss: 14.651 | acc: 51.44% (25718/50000) | agree : 43.67% (107529/246248): 100% 1924/1924 [08:24<00:00,  3.82it/s]
# [distill] epoch: 4 | lr: 0.0473 | loss: 14.446 | acc: 56.43% (28214/50000) | agree : 47.51% (116995/246248): 100% 1924/1924 [08:23<00:00,  3.82it/s]
# [distill] epoch: 5 | lr: 0.0452 | loss: 14.348 | acc: 59.59% (29793/50000) | agree : 49.41% (121669/246248): 100% 1924/1924 [08:23<00:00,  3.82it/s]
# [distill] epoch: 6 | lr: 0.0427 | loss: 14.270 | acc: 61.62% (30808/50000) | agree : 51.04% (125683/246248): 100% 1924/1924 [08:22<00:00,  3.83it/s]
# [distill] epoch: 7 | lr: 0.0397 | loss: 14.230 | acc: 62.77% (31384/50000) | agree : 51.94% (127913/246248): 100% 1924/1924 [08:23<00:00,  3.82it/s]
# [distill] epoch: 8 | lr: 0.0363 | loss: 14.187 | acc: 64.02% (32008/50000) | agree : 53.06% (130651/246248): 100% 1924/1924 [08:23<00:00,  3.82it/s]
# [distill] epoch: 9 | lr: 0.0327 | loss: 14.156 | acc: 65.13% (32567/50000) | agree : 53.76% (132372/246248): 100% 1924/1924 [08:24<00:00,  3.82it/s]
# [distill] epoch: 10 | lr: 0.0289 | loss: 14.118 | acc: 65.98% (32989/50000) | agree : 54.64% (134562/246248): 100% 1924/1924 [08:24<00:00,  3.81it/s]
# [eval] Loss: 1.265 | Acc: 60.660 (6066/10000): 100% 79/79 [00:06<00:00, 12.08it/s]
# [distill] epoch: 11 | lr: 0.0250 | loss: 14.090 | acc: 66.73% (33367/50000) | agree : 55.38% (136378/246248): 100% 1924/1924 [08:27<00:00,  3.79it/s]
# [distill] epoch: 12 | lr: 0.0211 | loss: 14.063 | acc: 67.51% (33753/50000) | agree : 56.06% (138057/246248): 100% 1924/1924 [08:28<00:00,  3.78it/s]
# [distill] epoch: 13 | lr: 0.0173 | loss: 14.042 | acc: 68.37% (34183/50000) | agree : 56.72% (139677/246248): 100% 1924/1924 [08:30<00:00,  3.77it/s]
# [distill] epoch: 14 | lr: 0.0137 | loss: 14.016 | acc: 68.81% (34407/50000) | agree : 57.41% (141359/246248): 100% 1924/1924 [08:31<00:00,  3.76it/s]
# [distill] epoch: 15 | lr: 0.0103 | loss: 13.988 | acc: 69.36% (34679/50000) | agree : 58.04% (142930/246248): 100% 1924/1924 [08:29<00:00,  3.77it/s]
# [distill] epoch: 16 | lr: 0.0073 | loss: 13.960 | acc: 70.03% (35013/50000) | agree : 59.00% (145281/246248): 100% 1924/1924 [08:29<00:00,  3.77it/s]
# [distill] epoch: 17 | lr: 0.0048 | loss: 13.945 | acc: 70.81% (35406/50000) | agree : 59.54% (146628/246248): 100% 1924/1924 [08:26<00:00,  3.80it/s]
# [distill] epoch: 18 | lr: 0.0027 | loss: 13.933 | acc: 71.04% (35520/50000) | agree : 59.92% (147542/246248): 100% 1924/1924 [08:28<00:00,  3.79it/s]
# [distill] epoch: 19 | lr: 0.0012 | loss: 13.923 | acc: 71.36% (35679/50000) | agree : 60.20% (148247/246248): 100% 1924/1924 [08:25<00:00,  3.81it/s]
# [distill] epoch: 20 | lr: 0.0003 | loss: 13.917 | acc: 71.37% (35685/50000) | agree : 60.52% (149029/246248): 100% 1924/1924 [08:28<00:00,  3.79it/s]
# [eval] Loss: 1.113 | Acc: 64.090 (6409/10000): 100% 79/79 [00:05<00:00, 13.70it/s]
